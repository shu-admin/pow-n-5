# %% [markdown]
# <a href="https://colab.research.google.com/github/shu-admin/pow-n-5/blob/main/_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [x**5 for x in range(1,10001)]
for i in range(len(l)):
  if (i+1)%10 == 0:
    print("%22d\n" %l[i])
  else:
    print("%22d" %l[i],end=' ')
# Out:
#                      1                     32                    243                   1024                   3125                   7776                  16807                  32768                  59049                 100000
#
#                 161051                 248832                 371293                 537824                 759375                1048576                1419857                1889568                2476099                3200000
#
#                4084101                5153632                6436343                7962624                9765625               11881376               14348907               17210368               20511149               24300000
#
#               28629151               33554432               39135393               45435424               52521875               60466176               69343957               79235168               90224199              102400000
#
# ...
